# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
from keras.datasets import fashion_mnist
from keras.utils.np_utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
data_train = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
import numpy as np

train_groups = [x_train[np.where(y_train==i)[0]] for i in np.unique(y_train)]
test_groups = [x_test[np.where(y_test==i)[0]] for i in np.unique(y_train)]
print('train groups:', [x.shape[0] for x in train_groups])
print('test groups:', [x.shape[0] for x in test_groups])
# Out:
# train groups: [6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000]
# test groups: [1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000, 1000]

# %%
def gen_random_batch(in_groups, batch_halfsize = 8):
  out_img_a, out_img_b, out_score = [], [], []
  all_groups = list(range(len(in_groups)))
  for match_group in [True, False]:
    group_idx = np.random.choice(all_groups, size = batch_halfsize)
    out_img_a += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in group_idx]

    if match_group:
      b_group_idx = group_idx
      out_score += [1]*batch_halfsize
    else:
      non_group_idx = [np.random.choice([i for i in all_groups if i!=c_idx]) for c_idx in group_idx]
      b_group_idx = non_group_idx
      out_score += [0]*batch_halfsize

    out_img_b += [in_groups[c_idx][np.random.choice(range(in_groups[c_idx].shape[0]))] for c_idx in b_group_idx]
  return np.array(out_img_a), np.array(out_img_b), np.array(out_score)

a, b, sim = gen_random_batch(train_groups, 3)
a.shape, b.shape, sim.shape
# Out:
# ((6, 28, 28), (6, 28, 28), (6,))

# %%
from matplotlib import pyplot as plt

fig, m_axs = plt.subplots(2, a.shape[0], figsize = (12, 6))
for c_a, c_b, c_d, (ax1, ax2) in zip(a, b, sim, m_axs.T):
  ax1.imshow(c_a)
  ax1.set_title('Image A')
  ax1.axis('off')
  ax2.imshow(c_b)
  ax2.set_title('Image B\n Similarity: %3.0f%%' % (100*c_d))
  ax2.axis('off')

# %%
img_shape = x_train[0].shape
input = tf.keras.layers.Input(shape=(*img_shape, 1))
xception_model = tf.keras.applications.Xception(
    include_top=False,
    weights=None,
    input_tensor=input,
    pooling='avg'
)

xception_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 28, 28, 1)]  0           []
#
#  block1_conv1 (Conv2D)          (None, 13, 13, 32)   288         ['input_1[0][0]']
#
#  block1_conv1_bn (BatchNormaliz  (None, 13, 13, 32)  128         ['block1_conv1[0][0]']
#  ation)
#
#  block1_conv1_act (Activation)  (None, 13, 13, 32)   0           ['block1_conv1_bn[0][0]']
#
#  block1_conv2 (Conv2D)          (None, 11, 11, 64)   18432       ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNormaliz  (None, 11, 11, 64)  256         ['block1_conv2[0][0]']
#  ation)
#
#  block1_conv2_act (Activation)  (None, 11, 11, 64)   0           ['block1_conv2_bn[0][0]']
#
#  block2_sepconv1 (SeparableConv  (None, 11, 11, 128)  8768       ['block1_conv2_act[0][0]']
#  2D)
#
#  block2_sepconv1_bn (BatchNorma  (None, 11, 11, 128)  512        ['block2_sepconv1[0][0]']
#  lization)
#
#  block2_sepconv2_act (Activatio  (None, 11, 11, 128)  0          ['block2_sepconv1_bn[0][0]']
#  n)
#
#  block2_sepconv2 (SeparableConv  (None, 11, 11, 128)  17536      ['block2_sepconv2_act[0][0]']
#  2D)
#
#  block2_sepconv2_bn (BatchNorma  (None, 11, 11, 128)  512        ['block2_sepconv2[0][0]']
#  lization)
#
#  conv2d (Conv2D)                (None, 6, 6, 128)    8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 6, 6, 128)    0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (BatchNorm  (None, 6, 6, 128)   512         ['conv2d[0][0]']
#  alization)
#
#  add (Add)                      (None, 6, 6, 128)    0           ['block2_pool[0][0]',
#                                                                   'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 6, 6, 128)   0           ['add[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 6, 6, 256)   33920       ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 6, 6, 256)   1024        ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 6, 6, 256)   0           ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 6, 6, 256)   67840       ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 6, 6, 256)   1024        ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_1 (Conv2D)              (None, 3, 3, 256)    32768       ['add[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 3, 3, 256)    0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 3, 3, 256)   1024        ['conv2d_1[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 3, 3, 256)    0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 3, 3, 256)   0           ['add_1[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 3, 3, 728)   188672      ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 3, 3, 728)   2912        ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 3, 3, 728)   0           ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 3, 3, 728)   536536      ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 3, 3, 728)   2912        ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_2 (Conv2D)              (None, 2, 2, 728)    186368      ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 2, 2, 728)    0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 2, 2, 728)   2912        ['conv2d_2[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 2, 2, 728)    0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 2, 2, 728)   0           ['add_2[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 2, 2, 728)   536536      ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 2, 2, 728)   0           ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 2, 2, 728)   536536      ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 2, 2, 728)   0           ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 2, 2, 728)   536536      ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block5_sepconv3[0][0]']
#  lization)
#
#  add_3 (Add)                    (None, 2, 2, 728)    0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_2[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 2, 2, 728)   0           ['add_3[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 2, 2, 728)   536536      ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 2, 2, 728)   0           ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 2, 2, 728)   536536      ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 2, 2, 728)   0           ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 2, 2, 728)   536536      ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block6_sepconv3[0][0]']
#  lization)
#
#  add_4 (Add)                    (None, 2, 2, 728)    0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_3[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 2, 2, 728)   0           ['add_4[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 2, 2, 728)   536536      ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 2, 2, 728)   0           ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 2, 2, 728)   536536      ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 2, 2, 728)   0           ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 2, 2, 728)   536536      ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block7_sepconv3[0][0]']
#  lization)
#
#  add_5 (Add)                    (None, 2, 2, 728)    0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_4[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 2, 2, 728)   0           ['add_5[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 2, 2, 728)   536536      ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 2, 2, 728)   0           ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 2, 2, 728)   536536      ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 2, 2, 728)   0           ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 2, 2, 728)   536536      ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block8_sepconv3[0][0]']
#  lization)
#
#  add_6 (Add)                    (None, 2, 2, 728)    0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_5[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 2, 2, 728)   0           ['add_6[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 2, 2, 728)   536536      ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 2, 2, 728)   0           ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 2, 2, 728)   536536      ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 2, 2, 728)   0           ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 2, 2, 728)   536536      ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 2, 2, 728)   2912        ['block9_sepconv3[0][0]']
#  lization)
#
#  add_7 (Add)                    (None, 2, 2, 728)    0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_6[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 2, 2, 728)   0           ['add_7[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 2, 2, 728)   536536      ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 2, 2, 728)   0           ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 2, 2, 728)   536536      ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 2, 2, 728)   0           ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 2, 2, 728)   536536      ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block10_sepconv3[0][0]']
#  alization)
#
#  add_8 (Add)                    (None, 2, 2, 728)    0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_7[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 2, 2, 728)   0           ['add_8[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 2, 2, 728)   536536      ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 2, 2, 728)   0           ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 2, 2, 728)   536536      ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 2, 2, 728)   0           ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 2, 2, 728)   536536      ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block11_sepconv3[0][0]']
#  alization)
#
#  add_9 (Add)                    (None, 2, 2, 728)    0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_8[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 2, 2, 728)   0           ['add_9[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 2, 2, 728)   536536      ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 2, 2, 728)   0           ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 2, 2, 728)   536536      ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 2, 2, 728)   0           ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 2, 2, 728)   536536      ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block12_sepconv3[0][0]']
#  alization)
#
#  add_10 (Add)                   (None, 2, 2, 728)    0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_9[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 2, 2, 728)   0           ['add_10[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 2, 2, 728)   536536      ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 2, 2, 728)   2912        ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 2, 2, 728)   0           ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 2, 2, 1024)  752024      ['block13_sepconv2_act[0][0]']
#  v2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 2, 2, 1024)  4096        ['block13_sepconv2[0][0]']
#  alization)
#
#  conv2d_3 (Conv2D)              (None, 1, 1, 1024)   745472      ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D)    (None, 1, 1, 1024)   0           ['block13_sepconv2_bn[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 1, 1, 1024)  4096        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_11 (Add)                   (None, 1, 1, 1024)   0           ['block13_pool[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 1, 1, 1536)  1582080     ['add_11[0][0]']
#  v2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 1, 1, 1536)  6144        ['block14_sepconv1[0][0]']
#  alization)
#
#  block14_sepconv1_act (Activati  (None, 1, 1, 1536)  0           ['block14_sepconv1_bn[0][0]']
#  on)
#
#  block14_sepconv2 (SeparableCon  (None, 1, 1, 2048)  3159552     ['block14_sepconv1_act[0][0]']
#  v2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 1, 1, 2048)  8192        ['block14_sepconv2[0][0]']
#  alization)
#
#  block14_sepconv2_act (Activati  (None, 1, 1, 2048)  0           ['block14_sepconv2_bn[0][0]']
#  on)
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  alAveragePooling2D)
#
# ==================================================================================================
# Total params: 20,860,904
# Trainable params: 20,806,376
# Non-trainable params: 54,528
# __________________________________________________________________________________________________

# %%
img_a_in = tf.keras.layers.Input(shape=(*img_shape, 1), name='in_a')
img_b_in = tf.keras.layers.Input(shape=(*img_shape, 1), name='in_b')
img_a_feat = xception_model(img_a_in)
img_b_feat = xception_model(img_b_in)
combined_features = tf.keras.layers.concatenate([img_a_feat, img_b_feat], name='merge_features')
combined_features = tf.keras.layers.Dense(16, activation = 'linear')(combined_features)
combined_features = tf.keras.layers.BatchNormalization()(combined_features)
combined_features = tf.keras.layers.Activation('relu')(combined_features)
combined_features = tf.keras.layers.Dense(4, activation = 'linear')(combined_features)
combined_features = tf.keras.layers.BatchNormalization()(combined_features)
combined_features = tf.keras.layers.Activation('relu')(combined_features)
combined_features = tf.keras.layers.Dense(1, activation = 'sigmoid')(combined_features)

similarity_model = tf.keras.Model(inputs = [img_a_in, img_b_in], outputs=[combined_features], name = 'Similarity_Model')
similarity_model.summary()
# Out:
# Model: "Similarity_Model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  in_a (InputLayer)              [(None, 28, 28, 1)]  0           []
#
#  in_b (InputLayer)              [(None, 28, 28, 1)]  0           []
#
#  xception (Functional)          (None, 2048)         20860904    ['in_a[0][0]',
#                                                                   'in_b[0][0]']
#
#  merge_features (Concatenate)   (None, 4096)         0           ['xception[0][0]',
#                                                                   'xception[1][0]']
#
#  dense (Dense)                  (None, 16)           65552       ['merge_features[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16)          64          ['dense[0][0]']
#  rmalization)
#
#  activation (Activation)        (None, 16)           0           ['batch_normalization_4[0][0]']
#
#  dense_1 (Dense)                (None, 4)            68          ['activation[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 4)           16          ['dense_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 4)            0           ['batch_normalization_5[0][0]']
#
#  dense_2 (Dense)                (None, 1)            5           ['activation_1[0][0]']
#
# ==================================================================================================
# Total params: 20,926,609
# Trainable params: 20,872,041
# Non-trainable params: 54,568
# __________________________________________________________________________________________________

# %%
similarity_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss='binary_crossentropy', metrics=['mae'])

callbacks_ = [
  tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=1,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
  ),
  tf.keras.callbacks.ReduceLROnPlateau(
      monitor='val_loss', 
      factor=0.2,
      patience=1, 
      min_lr=1e-4
  )
]

print(f'Train: X={x_train.shape} Y={y_train.shape}')
print(f'Train: X={x_test.shape} Y={y_test.shape}')
# Out:
# Train: X=(60000, 28, 28) Y=(60000,)
# Train: X=(10000, 28, 28) Y=(10000,)

# %%
train_a, train_b, train_sim = gen_random_batch(train_groups, x_train.shape[0]//2)
test_a, test_b, test_sim = gen_random_batch(test_groups, x_test.shape[0]//2)

loss_history = similarity_model.fit(
    [train_a, train_b],
    train_sim,
    validation_data=([test_a, test_b], test_sim),
    batch_size=100,
    epochs=20,
    callbacks=callbacks_
)
# Out:
# Epoch 1/20
# 600/600 [==============================] - 84s 110ms/step - loss: 0.3754 - mae: 0.2645 - val_loss: 0.2996 - val_mae: 0.1665 - lr: 0.0010
# Epoch 2/20
# 600/600 [==============================] - 64s 107ms/step - loss: 0.2422 - mae: 0.1555 - val_loss: 0.2597 - val_mae: 0.1391 - lr: 0.0010
# Epoch 3/20
# 600/600 [==============================] - 64s 106ms/step - loss: 0.2024 - mae: 0.1262 - val_loss: 0.2273 - val_mae: 0.1288 - lr: 0.0010
# Epoch 4/20
# 600/600 [==============================] - 64s 106ms/step - loss: 0.1771 - mae: 0.1081 - val_loss: 0.2089 - val_mae: 0.1084 - lr: 0.0010
# Epoch 5/20
# 600/600 [==============================] - 64s 106ms/step - loss: 0.1618 - mae: 0.0982 - val_loss: 0.2066 - val_mae: 0.1052 - lr: 0.0010
# Epoch 6/20
# 600/600 [==============================] - 63s 106ms/step - loss: 0.1463 - mae: 0.0878 - val_loss: 0.1777 - val_mae: 0.0970 - lr: 0.0010
# Epoch 7/20
# 600/600 [==============================] - 66s 110ms/step - loss: 0.1313 - mae: 0.0790 - val_loss: 0.1744 - val_mae: 0.0902 - lr: 0.0010
# Epoch 8/20
# 600/600 [==============================] - ETA: 0s - loss: 0.1230 - mae: 0.0727Restoring model weights from the end of the best epoch: 7.
# 600/600 [==============================] - 66s 110ms/step - loss: 0.1230 - mae: 0.0727 - val_loss: 0.1751 - val_mae: 0.0929 - lr: 0.0010
# Epoch 8: early stopping

# %%
plt.title('Loss history')
plt.plot(loss_history.history['loss'], label = 'training loss')
plt.plot(loss_history.history['val_loss'], label = 'validation loss')
plt.grid()
plt.legend()
plt.show()

# %%
def show_results(pv_a, pv_b, pv_sim, pred_sim, no_actual=False):
  fig, m_axs = plt.subplots(2, pv_a.shape[0], figsize = (2*len(pv_a), 6))
  for c_a, c_b, c_d, p_d, (ax1, ax2) in zip(pv_a, pv_b, pv_sim, pred_sim, m_axs.T):
    ax1.imshow(c_a)
    ax1.set_title('Image A' if no_actual else 'Image A\n Actual: %3.0f%%' % (100*c_d))
    ax1.axis('off')
    ax2.imshow(c_b)
    ax2.set_title('Image B\n Predicted: %3.0f%%' % (100*p_d))
    ax2.axis('off')

# %%
pv_a, pv_b, pv_sim = gen_random_batch(test_groups, 3)
pred_sim = similarity_model.predict([pv_a, pv_b])
show_results(pv_a, pv_b, pv_sim, pred_sim)

# %%
x_test_features = xception_model.predict(x_test, batch_size=100)

# %%
from sklearn.manifold import TSNE
tsne_obj = TSNE(n_components=2,
                init='pca',
                random_state=101,
                method='barnes_hut',
                n_iter=500,
                verbose=2)
tsne_features = tsne_obj.fit_transform(x_test_features)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 10000 samples in 0.017s...
# [t-SNE] Computed neighbors for 10000 samples in 8.265s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 1.137169
# [t-SNE] Computed conditional probabilities in 0.365s
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:986: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   FutureWarning,
# [t-SNE] Iteration 50: error = 64.0518646, gradient norm = 0.0041336 (50 iterations in 3.206s)
# [t-SNE] Iteration 100: error = 64.3760376, gradient norm = 0.0020190 (50 iterations in 3.014s)
# [t-SNE] Iteration 150: error = 64.2501678, gradient norm = 0.0014407 (50 iterations in 2.952s)
# [t-SNE] Iteration 200: error = 64.4190979, gradient norm = 0.0009331 (50 iterations in 2.972s)
# [t-SNE] Iteration 250: error = 64.5688324, gradient norm = 0.0006751 (50 iterations in 3.030s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.568832
# [t-SNE] Iteration 300: error = 1.8981392, gradient norm = 0.0010421 (50 iterations in 3.186s)
# [t-SNE] Iteration 350: error = 1.6320803, gradient norm = 0.0004587 (50 iterations in 3.361s)
# [t-SNE] Iteration 400: error = 1.5039175, gradient norm = 0.0003103 (50 iterations in 3.382s)
# [t-SNE] Iteration 450: error = 1.4062755, gradient norm = 0.0002399 (50 iterations in 3.319s)
# [t-SNE] Iteration 500: error = 1.3284776, gradient norm = 0.0001823 (50 iterations in 3.301s)
# [t-SNE] KL divergence after 500 iterations: 1.328478

# %%
obj_categories = ['T-shirt/top','Trouser','Pullover','Dress',
'Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot'
]
colors = plt.cm.rainbow(np.linspace(0, 1, 10))
plt.figure(figsize=(10, 10))

for c_group, (c_color, c_label) in enumerate(zip(colors, obj_categories)):
    plt.scatter(
      tsne_features[np.where(y_test == c_group), 0],
      tsne_features[np.where(y_test == c_group), 1],
      marker='o',
      color=c_color,
      linewidth='1',
      alpha=0.8,
      label=c_label
    )
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE on Testing Samples')
plt.legend(loc='best')
plt.show(block=False)
